# %%
import tensorflow
from tensorflow import keras
from tensorflow.keras.applications.resnet50 import ResNet50,preprocess_input,decode_predictions
from tensorflow.keras.preprocessing import image 
import numpy as np

# %%
model = ResNet50(weights='imagenet')

# %%
img_path = '3.webp'
# import matplotlib.pyplot as plt 
# plt.imshow(img_path)
img = image.load_img(img_path,target_size=(224,224))

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
x = image.img_to_array(img)

# %%
x
# Out:
# array([[[ 88., 107.,  85.],
#         [ 88., 107.,  85.],
#         [ 88., 107.,  85.],
#         ...,
#         [121., 136.,  97.],
#         [123., 138.,  99.],
#         [124., 140., 100.]],
#
#        [[ 95., 114.,  92.],
#         [112., 132., 109.],
#         [119., 139., 116.],
#         ...,
#         [125., 141., 101.],
#         [125., 141., 101.],
#         [133., 149., 109.]],
#
#        [[ 88., 107.,  85.],
#         [ 88., 107.,  85.],
#         [ 88., 107.,  85.],
#         ...,
#         [125., 140., 103.],
#         [125., 141., 101.],
#         [124., 140., 100.]],
#
#        ...,
#
#        [[168., 172., 173.],
#         [171., 176., 177.],
#         [182., 186., 187.],
#         ...,
#         [163., 169., 162.],
#         [146., 151., 145.],
#         [161., 167., 160.]],
#
#        [[156., 161., 162.],
#         [152., 156., 157.],
#         [170., 175., 176.],
#         ...,
#         [140., 146., 139.],
#         [140., 146., 139.],
#         [155., 161., 154.]],
#
#        [[148., 153., 153.],
#         [170., 175., 176.],
#         [180., 184., 185.],
#         ...,
#         [151., 159., 152.],
#         [127., 135., 128.],
#         [142., 148., 142.]]], dtype=float32)

# %%
x =np.expand_dims(x,axis=0)

# %%
x = preprocess_input(x)

# %%
output1 = model.predict(x)
# Out:
# 1/1 [==============================] - 0s 257ms/step

# %%
print('predivtion is : ',decode_predictions(output1,top=3)[0])
# Out:
# predivtion is :  [('n01697457', 'African_crocodile', 0.77935374), ('n01698640', 'American_alligator', 0.21931545), ('n01689811', 'alligator_lizard', 0.000867409)]
